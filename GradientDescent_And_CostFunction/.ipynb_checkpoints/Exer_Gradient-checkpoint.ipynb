# %%
import pandas as pd
import numpy as np

# %%
students_df = pd.read_csv(r'D:\Works\Artificial Intellegence\Machine Learning\GradientDescent_And_CostFunction\test_scores.csv')
students_df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %% [markdown]
# #### Changing dataframe series to arrray

# %%
x = np.array(students_df['math'])
y = np.array(students_df['cs'])

# %% [markdown]
# ### Gradient Descent Algorithm Implementation

# %%
import math

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iteration = 10000
    n = len(x)
    learning_rate = 0.0002
    prev_cost = float('inf') #initializing cost value higher than 1 to ensure intial if conditioin works
    
    for i in range(iteration):
        #y_predicted = mx+b
        #from linear equation y = mx+b 
        y_predicted = m_curr*x+b_curr

        #cost_function determines how well are we doing 
        #  at each step we should be reducing the cost
        #The most nearly the cost value difference with previous to zero the more accurate it is
        #If we find the optimim anwer is when the cost value donot change and remain same in each iteration
        cost = (2/n)*sum([val**2 for val in y-y_predicted])
        if math.isclose(prev_cost,cost,abs_tol=1e-4):
            print(f"conversion reched at iteration {i+1}")
            break
        
        md = -(2/n)*sum(x*(y-y_predicted)) #partial derivation of cost function(Mean Square Error) withrespect to m(coefficent)
        bd = -(2/n)*sum(y-y_predicted) #partial derivation of cost function(Mean Square Error) withrespect to b(intercept)

        m_curr = m_curr - learning_rate * md #gives the current point values after decrementing by learning rate and multiplying by slope 
        b_curr = b_curr - learning_rate * bd #gives the current point in the equation
        prev_cost = cost

        print(" m {}  b:{} Cost(C): {} iteration:{}".format(m_curr,b_curr,cost,i))

gradient_descent(x,y)
# Out:
#  m 0.09891800000000002  b:0.0013980000000000002 Cost(C): 10398.2 iteration:0
#  m 0.188468576032  b:0.002663817592 Cost(C): 8533.534137907302 iteration:1
#  m 0.2695388123929874  b:0.003809970298069408 Cost(C): 7005.30962317985 iteration:2
#  m 0.3429317875153011  b:0.004847790245306415 Cost(C): 5752.822400160355 iteration:3
#  m 0.4093745292255847  b:0.005787536421381067 Cost(C): 4726.3212357328075 iteration:4
#  m 0.46952521664984737  b:0.006638496299607258 Cost(C): 3885.0315033955335 iteration:5
#  m 0.5239797001063835  b:0.00740907784023707 Cost(C): 3195.5355356411856 iteration:6
#  m 0.5732774035723166  b:0.008106892779338137 Cost(C): 2630.4452090841205 iteration:7
#  m 0.6179066681933365  b:0.008738832030309935 Cost(C): 2167.314034829727 iteration:8
#  m 0.658309589769199  b:0.009311133944963032 Cost(C): 1787.745540195258 iteration:9
#  m 0.6948863981349007  b:0.009829446110352483 Cost(C): 1476.6625249666338 iteration:10
#  m 0.7279994218194848  b:0.010298881293522048 Cost(C): 1221.7081656258 iteration:11
#  m 0.7579766772562079  b:0.010724068088345346 Cost(C): 1012.7551782415021 iteration:12
#  m 0.7851151180986241  b:0.011109196766169286 Cost(C): 841.5035430170363 iteration:13
#  m 0.8096835768301668  b:0.0114580607844542 Cost(C): 701.1508113301138 iteration:14
#  m 0.8319254278066786  b:0.011774094364593408 Cost(C): 586.1218992180138 iteration:15
#  m 0.8520609981118711  b:0.012060406511156394 Cost(C): 491.8476341787119 iteration:16
#  m 0.8702897501075402  b:0.012319811809548711 Cost(C): 414.5832587353973 iteration:17
#  m 0.8867922572987808  b:0.012554858307168846 Cost(C): 351.25968137228057 iteration:18
#  m 0.9017319930870338  b:0.012767852754251532 Cost(C): 299.3615662390135 iteration:19
#  m 0.9152569501302737  b:0.01296088345443217 Cost(C): 256.82741910921067 iteration:20
#  m 0.9275011063516443  b:0.013135840951389036 Cost(C): 221.96770081265137 iteration:21
#  m 0.9385857521187595  b:0.013294436756484212 Cost(C): 193.39771544712428 iteration:22
#  m 0.9486206917406487  b:0.01343822030291842 Cost(C): 169.98260755890874 iteration:23
#  m 0.9577053311843193  b:0.013568594294346856 Cost(C): 150.79228347271822 iteration:24
#  m 0.9659296627858107  b:0.013686828599998719 Cost(C): 135.0644661584957 iteration:25
#  m 0.9733751567102406  b:0.013794072833944876 Cost(C): 122.17441610236968 iteration:26
#  m 0.9801155679916088  b:0.013891367743123316 Cost(C): 111.61011543576728 iteration:27
#  m 0.9862176671468584  b:0.013979655516931665 Cost(C): 102.95192958793173 iteration:28
#  m 0.9917419016016232  b:0.014059789120513123 Cost(C): 95.85593858305265 iteration:29
#  m 0.9967429944797166  b:0.014132540744190944 Cost(C): 90.040275868648 iteration:30
#  m 1.0012704866879427  b:0.014198609452751159 Cost(C): 85.27393202684107 iteration:31
#  m 1.0053692276660995  b:0.014258628110347012 Cost(C): 81.36757863012731 iteration:32
#  m 1.0090798196635178  b:0.014313169649622896 Cost(C): 78.16604774729832 iteration:33
#  m 1.0124390199431241  b:0.014362752747159443 Cost(C): 75.54216837084776 iteration:34
#  m 1.0154801048972388  b:0.014407846961460486 Cost(C): 73.3917149367414 iteration:35
#  m 1.0182331996820277  b:0.014448877384378545 Cost(C): 71.629267281915 iteration:36
#  m 1.0207255766359478  b:0.01448622885205567 Cost(C): 70.18481758894326 iteration:37
#  m 1.02298192543831  b:0.014520249757093002 Cost(C): 69.00098953911164 iteration:38
#  m 1.0250245976841352  b:0.014551255499712278 Cost(C): 68.03075921323037 iteration:39
#  m 1.0268738282980536  b:0.014579531612096278 Cost(C): 67.23558720993188 iteration:40
#  m 1.02854793598056  b:0.014605336586857837 Cost(C): 66.58388778554804 iteration:41
#  m 1.0300635046722406  b:0.014628904437656071 Cost(C): 66.04977420682276 iteration:42
#  m 1.0314355478335442  b:0.014650447017325204 Cost(C): 65.61203047942243 iteration:43
#  m 1.032677657167449  b:0.014670156116479243 Cost(C): 65.25326860729909 iteration:44
#  m 1.0338021372582633  b:0.014688205363381201 Cost(C): 64.95923790760406 iteration:45
#  m 1.0348201274602855  b:0.014704751943896893 Cost(C): 64.7182589457954 iteration:46
#  m 1.0357417122437487  b:0.014719938158571073 Cost(C): 64.52075960573926 iteration:47
#  m 1.0365760210911308  b:0.014733892832250253 Cost(C): 64.35889486660393 iteration:48
#  m 1.0373313189333986  b:0.014746732590215857 Cost(C): 64.22623518334564 iteration:49
#  m 1.0380150880220438  b:0.014758563013469032 Cost(C): 64.11751109265033 iteration:50
#  m 1.0386341020479306  b:0.014769479684611312 Cost(C): 64.02840389958226 iteration:51
#  m 1.0391944932411739  b:0.014779569134681585 Cost(C): 63.95537413060594 iteration:52
#  m 1.0397018131167355  b:0.014788909700328683 Cost(C): 63.895520938799955 iteration:53
#  m 1.0401610874674834  b:0.014797572299810718 Cost(C): 63.84646687656441 iteration:54
#  m 1.0405768661494694  b:0.014805621135508163 Cost(C): 63.80626345876951 iteration:55
#  m 1.0409532681526006  b:0.014813114329909761 Cost(C): 63.77331376512955 iteration:56
#  m 1.0412940224031677  b:0.014820104501371289 Cost(C): 63.74630900741694 iteration:57
#  m 1.041602504702422  b:0.01482663928535063 Cost(C): 63.724176541843725 iteration:58
#  m 1.0418817711671116  b:0.014832761806282487 Cost(C): 63.706037261559835 iteration:59
#  m 1.0421345885032363  b:0.0148385111047671 Cost(C): 63.69117067681632 iteration:60
#  m 1.0423634614129138  b:0.01484392252430468 Cost(C): 63.67898629570834 iteration:61
#  m 1.0425706574058466  b:0.014849028061406542 Cost(C): 63.669000168685834 iteration:62
#  m 1.042758229261171  b:0.014853856682551103 Cost(C): 63.66081566513473 iteration:63
#  m 1.0429280353621955  b:0.014858434611124528 Cost(C): 63.654107718435775 iteration:64
#  m 1.0430817581054623  b:0.014862785587188412 Cost(C): 63.64860991368522 iteration:65
#  m 1.0432209205664926  b:0.01486693110264777 Cost(C): 63.64410390517537 iteration:66
#  m 1.043346901587304  b:0.014870890614148884 Cost(C): 63.64041074327804 iteration:67
#  m 1.0434609494351577  b:0.014874681735815963 Cost(C): 63.63738376621607 iteration:68
#  m 1.043564194167838  b:0.014878320413735876 Cost(C): 63.63490277437219 iteration:69
#  m 1.0436576588279542  b:0.01488182108391937 Cost(C): 63.63286925572585 iteration:70
#  m 1.0437422695771554  b:0.014885196815303545 Cost(C): 63.63120247276378 iteration:71
#  m 1.043818864870645  b:0.01488845943921216 Cost(C): 63.62983625542851 iteration:72
#  m 1.0438882037628816  b:0.014891619666556194 Cost(C): 63.62871637271517 iteration:73
#  m 1.0439509734267374  b:0.014894687193935652 Cost(C): 63.62779837850965 iteration:74
#  m 1.044007795960603  b:0.014897670799693653 Cost(C): 63.6270458461029 iteration:75
#  m 1.0440592345508646  b:0.014900578430874294 Cost(C): 63.62642892125086 iteration:76
#  m 1.0441057990508051  b:0.01490341728194572 Cost(C): 63.625923136305666 iteration:77
#  m 1.0441479510311862  b:0.014906193866068207 Cost(C): 63.62550843831299 iteration:78
#  m 1.0441861083525483  b:0.014908914079613221 Cost(C): 63.6251683924697 iteration:79
#  m 1.0442206493045187  b:0.014911583260572625 Cost(C): 63.6248895293015 iteration:80
#  m 1.0442519163531307  b:0.014914206241436577 Cost(C): 63.624660809629006 iteration:81
#  m 1.0442802195332777  b:0.014916787397063966 Cost(C): 63.62447318607011 iteration:82
#  m 1.0443058395199045  b:0.014919330688019566 Cost(C): 63.624319243660366 iteration:83
#  m 1.0443290304083608  b:0.014921839699807213 Cost(C): 63.624192905316114 iteration:84
#  m 1.0443500222314583  b:0.014924317678387648 Cost(C): 63.624089190440806 iteration:85
#  m 1.0443690232381655  b:0.014926767562332851 Cost(C): 63.62400401708617 iteration:86
#  m 1.0443862219565128  b:0.014929192011935415 Cost(C): 63.62393403980915 iteration:87
#  m 1.0444017890611421  b:0.014931593435561276 Cost(C): 63.623876516784485 iteration:88
#  m 1.0444158790640032  b:0.014933974013506879 Cost(C): 63.62382920089381 iteration:89
#  m 1.0444286318449414  b:0.014936335719597101 Cost(C): 63.62379025046605 iteration:90
#  m 1.044440174037341  b:0.014938680340737868 Cost(C): 63.62375815612259 iteration:91
#  m 1.0444506202825503  b:0.014941009494617165 Cost(C): 63.62373168082162 iteration:92
#  m 1.0444600743655137  b:0.014943324645729785 Cost(C): 63.623709810720726 iteration:93
#  m 1.04446863024286  b:0.014945627119884545 Cost(C): 63.62369171490488 iteration:94
#  m 1.044476372973634  b:0.014947918117337686 Cost(C): 63.62367671238067 iteration:95
#  m 1.0444833795618855  b:0.014950198724682564 Cost(C): 63.62366424502656 iteration:96
#  m 1.04448971971947  b:0.014952469925613391 Cost(C): 63.62365385542255 iteration:97
#  m 1.04449545655661  b:0.014954732610669666 Cost(C): 63.62364516868105 iteration:98
#  m 1.0445006472070624  b:0.014956987586057822 Cost(C): 63.62363787755504 iteration:99
#  m 1.0445053433940827  b:0.014959235581637465 Cost(C): 63.62363173023439 iteration:100
#  m 1.044509591942794  b:0.014961477258151338 Cost(C): 63.62362652034297 iteration:101
#  m 1.0445134352440335  b:0.014963713213770602 Cost(C): 63.623622078740766 iteration:102
#  m 1.0445169116742747  b:0.014965943990020297 Cost(C): 63.62361826680608 iteration:103
#  m 1.0445200559757837  b:0.014968170077143666 Cost(C): 63.62361497092837 iteration:104
#  m 1.0445228996007734  b:0.014970391918958477 Cost(C): 63.623612097996 iteration:105
#  m 1.0445254710229683  b:0.014972609917253464 Cost(C): 63.623609571697386 iteration:106
#  m 1.0445277960196642  b:0.014974824435768433 Cost(C): 63.62360732948993 iteration:107
#  m 1.044529897927076  b:0.014977035803797447 Cost(C): 63.623605320115395 iteration:108
#  m 1.0445317978715067  b:0.014979244319450797 Cost(C): 63.62360350156427 iteration:109
#  m 1.0445335149786217  b:0.014981450252608075 Cost(C): 63.62360183940663 iteration:110
#  m 1.0445350665629083  b:0.014983653847591585 Cost(C): 63.6236003054249 iteration:111
#  m 1.0445364682991918  b:0.014985855325586588 Cost(C): 63.623598876492615 iteration:112
#  m 1.0445377343779094  b:0.014988054886832356 Cost(C): 63.62359753365621 iteration:113
#  m 1.04453887764568  b:0.014990252712605732 Cost(C): 63.6235962613818 iteration:114
#  m 1.0445399097325632  b:0.014992448967016852 Cost(C): 63.623595046938185 iteration:115
#  m 1.044540841167264  b:0.014994643798634808 Cost(C): 63.623593879891565 iteration:116
#  m 1.0445416814814326  b:0.01499683734195937 Cost(C): 63.62359275169024 iteration:117
#  m 1.0445424393040816  b:0.014999029718753337 Cost(C): 63.623591655325974 iteration:118
#  m 1.044543122447067  b:0.015001221039248709 Cost(C): 63.62359058505476 iteration:119
#  m 1.0445437379824702  b:0.015003411403238643 Cost(C): 63.623589536168915 iteration:120
#  m 1.0445442923126553  b:0.015005600901065999 Cost(C): 63.62358850481041 iteration:121
#  m 1.0445447912336894  b:0.01500778961451827 Cost(C): 63.62358748781709 iteration:122
#  m 1.0445452399927586  b:0.015009977617637772 Cost(C): 63.62358648259747 iteration:123
# conversion reched at iteration 125

# %% [markdown]
# ### conclusion

# %% [markdown]
# - we can define conversion rate
# - if the cost is same again and again the answer should be that

# %%
students_df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %% [markdown]
# ### Making Linear Regression Model

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(students_df[['cs']],students_df.math)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.88338816])

# %%
reg.intercept_
# Out:
# 5.051167395956433
